# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt 
from pandas import read_csv, read_excel 
# %matplotlib inline

# %%
df = read_excel('response_data.xlsx')
df.shape
# Out:
# (81, 78)

# %%
df.head()
# Out:
#                 Timestamp            role      automation_level  \
# 0 2024-05-07 12:02:02.314  Academic Staff   Partially automated
# 1 2024-05-07 12:02:44.474  Academic Staff   Partially automated
# 2 2024-05-07 12:15:52.603  Academic Staff   Partially automated
# 3 2024-05-07 12:18:30.870  Academic Staff  Not automated at all
# 4 2024-05-07 12:21:20.343  Academic Staff   Partially automated
#
#                              Automated_lib_functions  \
# 0                               Digital preservation
# 1  Online public access catalog (OPAC), Reporting...
# 2  Online public access catalog (OPAC), Electroni...
# 3                                                NaN
# 4  Circulation and lending, Online public access ...
#
#                                Automation_challenges rate_of_update/upgrade  \
# 0  Lack of funding, Technical infrastructure limi...                 Rarely
# 1  Resistance to change, Data Privacy and Securit...                 Rarely
# ...

# %%
df.columns
# Out:
# Index(['Timestamp', 'role', 'automation_level', 'Automated_lib_functions',
#        'Automation_challenges', 'rate_of_update/upgrade',
#        'Librabry_accessibility', 'recieved_training',
#        'Has_automation_improved_efficiency', 'How satisfied are you? ',
#        'Is further automation necessary?',
#        'What automation features  would you like? ',
#        'capacity of utilization of the  library',
#        'What  information formats do you prefer',
#        'challenges  in accessing  information  ',
#        'Are you familiar with the concept of the 4IR?',
#        'role of (4IR) to information needs ',
#        'How important is  the university librarygiven needs of 4IR? ',
#        'Is there adequate library_support for the 4IR? ',
#        '4IR technologies and tools used', 'library suggestions for 4IR? ',
#        'automation importance', ' importance of automating objectives',
# ...

# %%
df.dtypes
# Out:
# Timestamp                                                                                                                                                                                                                                      datetime64[ns]
# role                                                                                                                                                                                                                                                   object
# automation_level                                                                                                                                                                                                                                       object
# ...

# %%
df["How satisfied are you? "].value_counts().plot.pie(autopct='%1.1f%%', startangle=90)
plt.ylabel('')  # Hide y-label for better aesthetics
plt.title('Satisfaction Levels')
plt.show()

# %%
df["What automation codes"] = df["What automation features  would you like? "].astype('category').cat.codes

# %%
df.head()
# Out:
#                 Timestamp            role      automation_level  \
# 0 2024-05-07 12:02:02.314  Academic Staff   Partially automated
# 1 2024-05-07 12:02:44.474  Academic Staff   Partially automated
# 2 2024-05-07 12:15:52.603  Academic Staff   Partially automated
# 3 2024-05-07 12:18:30.870  Academic Staff  Not automated at all
# 4 2024-05-07 12:21:20.343  Academic Staff   Partially automated
#
#                              Automated_lib_functions  \
# 0                               Digital preservation
# 1  Online public access catalog (OPAC), Reporting...
# 2  Online public access catalog (OPAC), Electroni...
# 3                                                NaN
# 4  Circulation and lending, Online public access ...
#
#                                Automation_challenges rate_of_update/upgrade  \
# 0  Lack of funding, Technical infrastructure limi...                 Rarely
# 1  Resistance to change, Data Privacy and Securit...                 Rarely
# ...

# %%
df["What automation codes"].plot.hist(bins=8, edgecolor='black')
plt.xlabel('What automation feature codes')
plt.ylabel('Frequency')
plt.title('Histogram of What automation features')
plt.show()

# %%
# Plotting a bar chart
df['recieved_training'].value_counts().plot.bar()
plt.xlabel('Recieved Training')
plt.ylabel('Frequency')
plt.title('Bar Chart of Participants that Recieved Training')
plt.show()

# %%
df["role"].value_counts().plot.pie(autopct='%1.1f%%', startangle=90)
plt.ylabel('')  # Hide y-label for better aesthetics
plt.title("Participnats' role at the University lIbrary")
plt.show()

# %%
# Plotting a count plot
sns.countplot(data=df, x='Librabry_accessibility', hue='Librabry_accessibility', native_scale= True,gap=0)
plt.xlabel('Those that recieved library Access')
plt.ylabel('Count of Participants')
plt.title('Count Plot of Participants with access to the Library')
plt.show()

# %%
# Creating a crosstab for heatmap
plt.figure(figsize=(9,9))
heatmap_data = pd.crosstab(df['role'], df['recieved_training'])
# Plotting a heatmap
sns.heatmap(heatmap_data, annot=True, cmap='coolwarm')
plt.title('Heatmap of individuals with Training by role')
plt.show()

# %%
# Creating a crosstab for heatmap
heatmap_data = pd.crosstab(df['role'], df['recieved_training'])

# Plotting a heatmap
sns.scatterplot(heatmap_data)
plt.title('Heatmap of individuals with Training by role')
plt.show()

# %%
# Plotting a pair plot
sns.pairplot(df, hue='role')
plt.show()

# %%
plt.figure(figsize=(9,9))
df["How satisfied are you? "].value_counts().plot.pie(autopct='%1.1f%%', startangle=90)
plt.ylabel('')  # Hide y-label for better aesthetics
plt.title("Participnats' Satisfaction with Library Automation")
plt.show()

# %%
sns.countplot(data=df, x='Is further automation necessary?', hue='Is further automation necessary?')
plt.xlabel('Vote For Further Automation')
plt.ylabel('Count of Participants')
plt.title('Count Plot of Participants For Further Automation')
plt.show()

# %%
#What automation features  would you like? 
plt.figure(figsize=(15,15))
df['What automation features  would you like? '].value_counts().plot.pie(autopct='%1.1f%%', startangle=90)
plt.ylabel('')  # Hide y-label for better aesthetics
plt.title("Automation Feeatures Needed")
plt.show()

# %%
plt.figure(figsize=(15,15))
df['What  information formats do you prefer'].value_counts().plot.pie(autopct='%1.1f%%', startangle=90)
plt.ylabel('')  # Hide y-label for better aesthetics
plt.title("Prefered infomation Formats")
plt.show()

# %%
sns.countplot(data=df, x='Are you familiar with the concept of the 4IR?', hue='Are you familiar with the concept of the 4IR?')
plt.xlabel('Vote For 4IR')
plt.ylabel('Count of Participants')
plt.title('Knowledge Of Participants about the 4IR')
plt.show()

# %%
sns.countplot(data=df, x='Is there adequate library_support for the 4IR? ', hue='Is there adequate library_support for the 4IR? ')
plt.xlabel('Vote For library Support')
plt.ylabel('Count of Participants')
plt.title('Adequacy in the Library support by the university')
plt.show()

# %%
# cross tabualtion between library support and role
# Creating a crosstab for heatmap
count_data = pd.crosstab(df['role'], df['Is there adequate library_support for the 4IR? '])

# Plotting a heatmap
sns.heatmap(count_data, annot=True, cmap='coolwarm')
plt.title('Heatmap of individuals reply about library support by role')
plt.show()

# %%
plt.figure(figsize=(8,8))
df['automation importance'].value_counts().plot.pie(autopct='%1.1f%%')
plt.ylabel('')  # Hide y-label for better aesthetics
plt.title("How Important Is Automation")
plt.show()

# %%
plt.figure(figsize=(8,8))
df['automation_level'].value_counts().plot.pie(autopct='%1.1f%%')
plt.ylabel('')  # Hide y-label for better aesthetics
plt.title("How Important Is Automation")
plt.show()

# %%
# cross tabualtion between library support and role
# Creating a crosstab for heatmap
count_data = pd.crosstab(df['role'], df['automation_level'])

# Plotting a heatmap
sns.heatmap(count_data, annot=True, cmap='coolwarm')
plt.title('Reply of individuals about level of automation in the university library support by role')
plt.show()
